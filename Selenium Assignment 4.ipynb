# %%
#Importing Libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import os
import urllib
import requests

# %% [markdown]
# # 1
#
# Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
#1
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window()  #maximizing window
time.sleep(3)
url="https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"   #"url"
driver.get(url) #loading url
time.sleep(2)

#creating empty Boxex
rank=[]
videon=[]
uploader=[]
views=[]
uploadd=[]

for i in range(1,31):
    #Rank
    dt=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[{}]/td[1]".format(i))
    for d in dt:
        rank.append(d.text)
    #video name
    vi=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[{}]/td[2]".format(i))
    for c in vi:
        videon.append(c.text)
        videon = [x.split("[")[0] for x in videon] #cleaning data
        
    #Uploader
    l=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[{}]/td[3]".format(i))
    for g in l:
        uploader.append(g.text)
    #Views
    vs=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[{}]/td[4]".format(i))
    for h in vs:
        views.append(h.text)
   #Upload date
    up=driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[{}]/td[5]".format(i))
    for c in up:
        uploadd.append(c.text)

time.sleep(2)
#creating dataframe
ans1=pd.DataFrame({})
ans1["Rank"]=rank
ans1["Video Name"]=videon
ans1["Uploader"]=uploader
ans1["Views (billions)"]=views 
ans1["Upload Date"]=uploadd
ans1.set_index("Rank", inplace=True)
ans1
# Out:
#                                        Video Name  \
# Rank
# 1.                             "Baby Shark Dance"
# 2.                                    "Despacito"
# 3.                         "Johny Johny Yes Papa"
# 4.                                 "Shape of You"
# 5.                                "See You Again"
# 6.     "Masha and the Bear – Recipe for Disaster"
# 7.                                  "Uptown Funk"
# 8.    "Learning Colors – Colorful Eggs on a Farm"
# 9.                                    "Bath Song"
# 10.                               "Gangnam Style"
# 11.                 "Phonics Song with Two Words"
# 12.                                       "Sugar"
# 13.                                       "Sorry"
# 14.                              "Dame Tu Cosita"
# 15.                                        "Roar"
# 16.                              "Counting Stars"
# 17.                           "Thinking Out Loud"
# 18.                                  "Dark Horse"
# ...

# %% [markdown]
# # Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#2
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window() #maximizing window
time.sleep(3)
url="https://www.bcci.tv/"   #"url"
driver.get(url) #loading url
time.sleep(3)

#clicking on fixture button
fixtures=driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
try:
    fixtures.click()

except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))
time.sleep(3)

#creating boxex
mt=[]
series=[]
place=[]
date=[]
ti=[]
month=[]

#Match Title 
d=driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
for i in d:
    mt.append(i.text)

#Series    
s=driver.find_elements_by_xpath("//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in s:
    series.append(i.text)

#Place
p=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
for i in p:
    place.append(i.text)
    
#Date    
z=driver.find_elements_by_xpath("//span[@class='fixture__date']")
for i in z:
    date.append(i.text)
    
#Month
h=driver.find_elements_by_xpath("//span[@class='fixture__month']")
for i in h:
    month.append(i.text)
    
#time
v=driver.find_elements_by_xpath("//span[@class='fixture__time']")
for i in v:
    ti.append(i.text)
    
time.sleep(2)
#creating dataframe
ans2=pd.DataFrame({})
ans2["Match Title"]=mt
ans2["Series"]=series
ans2["Place"]=place
ans2["Date"]=date 
ans2["Month"]=month
ans2["Date"]=ans2["Date"]+" " + ans2["Month"]   #adding date and month in one column
ans2.drop("Month",axis=1,inplace=True)
ans2["Time"]=ti
ans2
# Out:
#   Match Title                       Series                        Place  \
# 0       Final  ICC WORLD TEST CHAMPIONSHIP  The Ageas Bowl, Southampton
# 1    1st Test         ENGLAND V INDIA 2021     Trent Bridge, Nottingham
# 2    2nd Test         ENGLAND V INDIA 2021               Lord's, London
# 3    3rd Test         ENGLAND V INDIA 2021            Headingley, Leeds
# 4    4th Test         ENGLAND V INDIA 2021             The Oval, London
# 5    5th Test         ENGLAND V INDIA 2021     Old Trafford, Manchester
#
#            Date       Time
# 0       18 JUNE  15:00 IST
# 1     04 AUGUST  15:30 IST
# 2     12 AUGUST  15:30 IST
# 3     25 AUGUST  15:30 IST
# 4  02 SEPTEMBER  15:30 IST
# 5  10 SEPTEMBER  15:30 IST

# %% [markdown]
# # 3
# Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#2
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window() #maximizing windows
time.sleep(3)
url="https://www.guru99.com/"   #"url"
driver.get(url) #loading url
time.sleep(3)

#Selecting selenium in texting column
s=driver.find_element_by_xpath("//*[@id='java_technologies']/li[3]/a")
s.click()
time.sleep(3)


# selecting "Selenium Exception Handling (Common Exceptions List)"
driver.find_element_by_xpath("/html/body/div[2]/section[3]/div/div[1]/main/div/div/div/div/div/div/div[2]/table[5]/tbody/tr[34]/td[1]/a/strong").click()

#creating empty boxes
en=[]
des=[]


for i in range(2,43):
    #Exception name
    dt=driver.find_elements_by_xpath("//*[@id='g-mainbar']/div[1]/div/div/div/div/div/div[2]/table/tbody/tr[{}]/td[1]".format(i))
    for d in dt:
        en.append(d.text)
      
    #Description
    gt=driver.find_elements_by_xpath("//*[@id='g-mainbar']/div[1]/div/div/div/div/div/div[2]/table/tbody/tr[{}]/td[2]".format(i))
    for c in gt:
        des.append(c.text)

time.sleep(2)
#creating dataframe
ans3=pd.DataFrame({})
ans3["Exception Name"]=en
ans3["Description"]=des  
ans3
# Out:
#                          Exception Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# # 4
# Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#4
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window()
time.sleep(3)
url="http://statisticstimes.com/"   #"url"
driver.get(url)  #loading url
time.sleep(2)

#Selecting india in economy dropdown
gdp=driver.find_element_by_xpath("//*[@id='top']/div[2]/div[2]/div/a[3]")

try:
    gdp.click()

except ElementNotInteractableException:
    driver.get(gdp.get_attribute('href'))
time.sleep(3)

#selecting state gdp
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a").click()

#creating empty boxes
rank=[]
state=[]
gs19=[]
gs18=[]
share=[]
gd=[]

#extraxting data
for i in range(1,34):
    #Rank
    dt=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[{}]/td[1]".format(i))
    for d in dt:
        rank.append(d.text)
    #State
    vi=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[{}]/td[2]".format(i))
    for c in vi:
        state.append(c.text)
    #GSDP (Cr INR at Current prices)19-20
    l=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[{}]/td[3]".format(i))
    for g in l:
        gs19.append(g.text)
    #GSDP (Cr INR at Current prices)18-19
    vs=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[{}]/td[4]".format(i))
    for h in vs:
        gs18.append(h.text)
   #share
    up=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[{}]/td[5]".format(i))
    for c in up:
        share.append(c.text)
    #GDP($Billion)    
    dt=driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[{}]/td[5]".format(i))
    for z in dt:
        gd.append(z.text)

time.sleep(2)
#creating dataframe
ans4=pd.DataFrame({})
ans4["Rank"]=rank
ans4["State"]=state
ans4["GSDP (Cr INR at Current prices)19-20"]=gs19
ans4["GSDP (Cr INR at Current prices)18-19"]=gs18 
ans4["Share"]=share
ans4["GDP($Billion)"]=gd
ans4.set_index("Rank", inplace=True) #setting rank column as index
ans4
# Out:
#                           State GSDP (Cr INR at Current prices)19-20  \
# Rank
# 1                   Maharashtra                                    -
# 2                    Tamil Nadu                            1,845,853
# 3                 Uttar Pradesh                            1,687,818
# 4                       Gujarat                                    -
# 5                     Karnataka                            1,631,977
# 6                   West Bengal                            1,253,832
# 7                     Rajasthan                            1,020,989
# 8                Andhra Pradesh                              972,782
# 9                     Telangana                              969,604
# 10               Madhya Pradesh                              906,672
# 11                       Kerala                                    -
# 12                        Delhi                              856,112
# ...

# %% [markdown]
# # 5
# Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
#5
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window()  #maximizing windows
time.sleep(3)
url="https://github.com/"   #"url"
driver.get(url)  #loading url
time.sleep(3)

#Selecting Trending from explore
tred=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a")

try:
    tred.click()

except ElementNotInteractableException:
    driver.get(tred.get_attribute('href'))
time.sleep(3)


time.sleep(3)

# Getting urls for data extraction
urls=[]
url=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
for i in url:
    urls.append(i.get_attribute("href"))

#creating boxes    
rt=[]
rd=[]
cc=[]
lu=[]


#extracting data
for i in urls:
    driver.get(i)
    time.sleep(3)
    
#respositery title
    try:
        c=driver.find_element_by_xpath("//*[@id='js-repo-pjax-container']/div[1]/div[1]/div")
        rt.append(c.text)
    except NoSuchElementException:
        rt.append("--")
#repositery description
    try:
        z=driver.find_element_by_xpath("//p[@class='f4 mt-3']")
        rd.append(z.text)
    except NoSuchElementException:
        rd.append("--")
#Contributor count
    try:
        d=driver.find_element_by_xpath('//*[@id="repo-content-pjax-container"]/div/div[2]/div[2]/div/div[5]/div/h2/a/span')
        cc.append(d.text)
    except NoSuchElementException:
        cc.append("--")
#language used
    try:
        c=driver.find_element_by_xpath("//*[@id='repo-content-pjax-container']/div/div[2]/div[2]/div/div[6]/div/ul")
        lu.append(c.text)
    except NoSuchElementException:
        lu.append("--")
    
time.sleep(2)
#creating dataframe
ans5=pd.DataFrame({})
ans5["Repositery Title"]=rt
ans5["Repositery Description"]=rd
ans5["Contributor count"]=cc
ans5["Languages"]=lu

ans5
# Out:
#                                      Repositery Title  \
# 0                          facebookresearch\n/\nAugLy
# 1                               programthink\n/\nzhao
# 2                              megaease\n/\neasegress
# 3                                keras-team\n/\nkeras
# 4                         ibraheemdev\n/\nmodern-unix
# 5                        tailwindlabs\n/\ntailwindcss
# 6                                      n8n-io\n/\nn8n
# 7                             harvester\n/\nharvester
# 8                         organicmaps\n/\norganicmaps
# 9                               longhorn\n/\nlonghorn
# 10                                rancher\n/\nrancher
# 11                              rustdesk\n/\nrustdesk
# 12                                   kwai\n/\nDouZero
# 13                        cariboulabs\n/\ncariboulite
# 14                            willmcgugan\n/\ntextual
# 15                                  prisma\n/\nprisma
# ...

# %% [markdown]
# # 6
# Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")  #maximizing window
driver.maximize_window()
time.sleep(3)
url="https://www.billboard.com/"   #"url"
driver.get(url)  #loading url
time.sleep(5)

#getting hot 100 songs from dropdown
chart=driver.find_element_by_xpath("//*[@id='menu-charts-desktop']/span/span/span[1]/ul/li[1]/a")

try:
    chart.click()

except ElementNotInteractableException:
    driver.get(chart.get_attribute('href'))
time.sleep(3)


#creating boxes
sname=[]
aname=[]
lr=[]
pr=[]
wb=[]


#Song
c=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
for i in c:
    sname.append(i.text)

#Artist
z=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
for v in z: 
    aname.append(v.text)

#Last rank
d=driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--last"]')
for h in d:    
    lr.append(h.text)

#Peak Rank
c=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for t in c:
    pr.append(t.text)

#WKS on chart
g=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for b in g:
    wb.append(b.text)

time.sleep(2)
#creating dataframe
ans6=pd.DataFrame({})
ans6["Song"]=sname
ans6["Artist"]=aname
ans6["Last Week Rank"]=lr
ans6["Peak rank"]=pr
ans6["Weeks on board"]=wb
ans6
# Out:
#                     Song                                    Artist  \
# 0                 Butter                                       BTS
# 1               Good 4 U                            Olivia Rodrigo
# 2             Levitating                 Dua Lipa Featuring DaBaby
# 3    Leave The Door Open  Silk Sonic (Bruno Mars & Anderson .Paak)
# 4        Save Your Tears                The Weeknd & Ariana Grande
# ..                   ...                                       ...
# 95     All I Know So Far                                      P!nk
# 96               Hold On                             Justin Bieber
# 97         Wasted On You                             Morgan Wallen
# 98               Outside                   MO3 X OG Bobby Billions
# 99  Botella Tras Botella                 Gera MX + Christian Nodal
#
#    Last Week Rank Peak rank Weeks on board
# 0               1         1              2
# 1               2         1              3
# ...

# %% [markdown]
# # 7
# Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window() #maximizing windows
time.sleep(3)
url="https://www.naukri.com/"   #"url"
driver.get(url) #loading url
time.sleep(3)


#clicking on recruiters
driver.find_element_by_xpath("//*[@id='root']/div[1]/div/ul[1]/li[2]/a").click()
time.sleep(5)

#shifting tab since the recruiters opened in new tab
driver.switch_to.window(driver.window_handles[-4])  #we have used value -4 because there are 3 add popups
time.sleep(2)

#searching search bar
searchb=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input")

#putting key words
keyword="Data Science"
searchb.send_keys(keyword)

#cliacking on search button
driver.find_element_by_xpath("//*[@id='qsbFormBtn']").click()
time.sleep(3)


#ccreating expty boxes
name=[]
des=[]
com=[]
sh=[]
lo=[]



#extracting data
#name
c=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
for i in c:
    name.append(i.text)

#Designation
z=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
for v in z: 
    des.append(v.text)

#Company
d=driver.find_elements_by_xpath('//a[@class="ellipsis"]')
for h in d:    
    com.append(h.text)
f=com[1::2]

#Skill they hire
c=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for t in c:
    sh.append(t.text)

#Location
urls=[]
location=driver.find_elements_by_xpath("//a[@class='ellipsis']")
for i in location:
    urls.append(i.get_attribute("href"))
urls=urls[0::2]

for i in urls:
    driver.get(i)
    time.sleep(3)
    t=driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[1]/div[2]/div[5]/a")
    try:
        lo.append(t.text)
    except NoSuchElementException:
        lo.append("--")



time.sleep(2)
#creating dataframe
ans7=pd.DataFrame({})
ans7["Name"]=name
ans7["Designation"]=des
ans7["Company"]=f
ans7["Skill they hire"]=sh
ans7["Location"]=lo
ans7
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                    Ruchi Dhote
# 14                             Mahesh Babu Channa
# 15                                   Kapil Devang
# 16                                  Manisha Yadav
# 17                                    Riya Rajesh
# ...

# %% [markdown]
# # 8
# Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window() #maximizing windows
time.sleep(3)
url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"   #"url"
driver.get(url) #loading url
time.sleep(3)

#creating boxes
name=[]
aut=[]
vs=[]
pu=[]
ge=[]


#extracting data
for i in range(0,101):
#Book Name
    c=driver.find_elements_by_xpath("/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{}]/td[2]".format(i))
    for q in c:
        name.append(q.text)

#AUthor
    z=driver.find_elements_by_xpath("/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{}]/td[3]".format(i))
    for v in z:
        aut.append(v.text)

#Volumes sold
    d=driver.find_elements_by_xpath("/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{}]/td[4]".format(i))    
    for h in d:
        vs.append(h.text)

#Publisher
    c=driver.find_elements_by_xpath("/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{}]/td[5]".format(i))
    for t in c:
        pu.append(t.text)

#Genre
    g=driver.find_elements_by_xpath("/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{}]/td[6]".format(i))
    for b in g:
        ge.append(b.text)
    
time.sleep(2)
#creating dataframe
ans8=pd.DataFrame({})
ans8["Book Name"]=name
ans8["Author"]=aut
ans8["Volumes sold"]=vs
ans8["Publisher"]=pu
ans8["Genre"]=ge
ans8
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %% [markdown]
# # 9
# Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window() #maximizing windows
time.sleep(3)
url="https://www.imdb.com/list/ls095964455/"   #"url"
driver.get(url) #loading url
time.sleep(3)

#creating boxes
name=[]
year=[]
ge=[]
rt=[]
rating=[]
votes=[]


#extracting data
#name
c=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
for i in c:
    name.append(i.text)

#Year span
z=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in z:
    year.append(i.text)

#Genre
v=driver.find_elements_by_xpath("//span[@class='genre']")
for i in v:
    ge.append(i.text)

#Run Time
y=driver.find_elements_by_xpath("//span[@class='runtime']")
for i in y:
    rt.append(i.text)

#Rating
t=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']")
for i in t:
    rating.append(i.text)

#votes
r=driver.find_elements_by_xpath("//span[@name='nv']")
for i in r:
    votes.append(i.text)

time.sleep(2)
#creating dataframe
ans9=pd.DataFrame({})
ans9["Name"]=name
ans9["Year span"]=year
ans9["Genre"]=ge
ans9["Run time"]=rt
ans9["Rating"]=rating
ans9["Votes"]=votes
ans9
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Rating      Votes
# 0    57 min    9.3  1,823,384
# ...

# %% [markdown]
# # 10
# Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code

# %%
#importing webdriver
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window()   #maximizing windows
time.sleep(3)
url="https://archive.ics.uci.edu/ml/index.php"   #"url"
driver.get(url)  #loading url
time.sleep(3)

#clicking on view all data sets
driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]").click()


#creating empty boxes
time.sleep(3)
name=[]
dtype=[]
task=[]
at=[]
noi=[]
noa=[]
year=[]


#extracting dataset
for i in range(2,590):
    
#Dataset name
    c=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[1]/table/tbody/tr/td[2]/p".format(i))
    for a in c:
        name.append(a.text)

# Data Type
    z=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[2]/p".format(i))
    for c in z:
        dtype.append(c.text)

#Task
    v=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[3]".format(i))
    for t in v:
        task.append(t.text)

#Attribute type
    y=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[4]".format(i))
    for u in y:
        at.append(u.text)

#NO. of instances
    t=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[5]".format(i))
    for r in t:
        noi.append(r.text)

#No. of attribute
    r=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[6]".format(i))
    for w in r:
        noa.append(w.text)

#Year
    w=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[{}]/td[7]".format(i))
    for y in w:
        year.append(y.text)


    
time.sleep(2)
#creating dataframe
ans10=pd.DataFrame({})
ans10["Dataset Name"]=name
ans10["Data Type"]=dtype
ans10["Task"]=task
ans10["Attribute Type"]=at
ans10["No. of instances"]=noi
ans10["No. of Attributes"]=noa
ans10["Year"]=year
ans10
# Out:
#                          Dataset Name      Data Type                  Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                   Attribute Type No. of instances No. of Attributes   Year
# ...
